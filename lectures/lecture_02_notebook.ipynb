# %% [markdown]
# # EE 451: Communications Systems
# ## Lesson 2 - Signal Analysis Fundamentals & I/Q Representation
#
# ### Learning Objectives
# By the end of this lesson, you will be able to:
# - Apply convolution to analyze linear systems with arbitrary input signals
# - Distinguish between energy signals and power signals, and calculate energy/power
# - Represent sinusoidal signals as rotating phasors in the complex plane
# - Explain the concept and utility of analytic signals in communications
# - Use impulse and step functions to characterize system behavior
# - Express communication signals in I/Q form and convert between rectangular and polar representations
#
# ### Textbook Reference
# Haykin & Moher, Chapter 2.1

# %%
# Setup: Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.fft import fft, fftfreq
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import warnings
warnings.filterwarnings('ignore')

# Matplotlib settings for publication-quality plots
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3

print("Setup complete! NumPy version:", np.__version__)
print("Matplotlib backend:", plt.get_backend())
# Out:
# Setup complete! NumPy version: 2.4.1
# Matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# ## 1. Impulse and Step Functions
#
# ### Unit Impulse δ(t)
# The unit impulse (Dirac delta function) is a fundamental signal in communications:
#
# **Informal definition:**
# - $\delta(t) = 0$ for $t \neq 0$
# - $\int_{-\infty}^{\infty} \delta(t) dt = 1$
#
# **Sifting property:**
# $$\int_{-\infty}^{\infty} f(t)\delta(t - t_0) dt = f(t_0)$$
#
# Physical interpretation: Idealized "click" or "tap" - no true physical impulse exists, but approximations are useful.
#
# ### Unit Step u(t)
# $$u(t) = \begin{cases} 0 & t < 0 \\ 1 & t \geq 0 \end{cases}$$
#
# Relationship to impulse: $\delta(t) = \frac{du(t)}{dt}$

# %%
# Visualize impulse and step functions
t = np.linspace(-2, 5, 1000)

# Step function
u = np.heaviside(t, 1)

# Approximate impulse (very narrow pulse)
delta_approx = np.zeros_like(t)
impulse_idx = np.argmin(np.abs(t))  # Find index closest to t=0
delta_approx[impulse_idx] = 10  # Height scaled for visibility

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot step function
ax1.plot(t, u, 'b-', linewidth=2.5)
ax1.axhline(y=0, color='k', linewidth=0.5)
ax1.axvline(x=0, color='k', linewidth=0.5)
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Amplitude')
ax1.set_title('Unit Step Function: $u(t)$')
ax1.grid(True, alpha=0.3)
ax1.set_ylim(-0.5, 1.5)

# Plot impulse (approximation)
ax2.stem([0], [1], basefmt=' ', linefmt='r-', markerfmt='ro')
ax2.axhline(y=0, color='k', linewidth=0.5)
ax2.axvline(x=0, color='k', linewidth=0.5)
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Amplitude')
ax2.set_title('Unit Impulse Function: $\\delta(t)$')
ax2.grid(True, alpha=0.3)
ax2.set_xlim(-2, 5)
ax2.set_ylim(-0.2, 1.5)

plt.tight_layout()
plt.show()

print("Step function: Switches from 0 to 1 at t=0")
print("Impulse function: Infinite height at t=0, zero elsewhere, but area = 1")
# Out:
# Step function: Switches from 0 to 1 at t=0
# Impulse function: Infinite height at t=0, zero elsewhere, but area = 1

# %%
# Worked Example 1: Sifting property
# Evaluate ∫ cos(2πt) δ(t - 0.5) dt from -∞ to ∞

t0 = 0.5  # Impulse location
f_t0 = np.cos(2 * np.pi * t0)  # Evaluate f(t) at t = t0

print("Worked Example 1: Sifting Property")
print("="*50)
print(f"Evaluate: ∫ cos(2πt) δ(t - 0.5) dt")
print(f"\nUsing sifting property: f(t₀) where t₀ = {t0}")
print(f"Result: cos(2π × {t0}) = cos(π) = {f_t0:.4f}")
print(f"\nThe impulse 'picks out' the value of the function at t = {t0}")
# Out:
# Worked Example 1: Sifting Property
# ==================================================
# Evaluate: ∫ cos(2πt) δ(t - 0.5) dt
#
# Using sifting property: f(t₀) where t₀ = 0.5
# Result: cos(2π × 0.5) = cos(π) = -1.0000
#
# The impulse 'picks out' the value of the function at t = 0.5

# %% [markdown]
# ## 2. Convolution
#
# Convolution is fundamental to understanding how signals pass through systems.
#
# **Convolution integral:**
# $$y(t) = x(t) * h(t) = \int_{-\infty}^{\infty} x(\tau)h(t - \tau) d\tau$$
#
# where:
# - $x(t)$ is the input signal
# - $h(t)$ is the system impulse response
# - $y(t)$ is the output signal
#
# **Physical interpretation:** The output is the sum of scaled and shifted impulse responses.
#
# **Properties:**
# - Commutative: $x * h = h * x$
# - Associative: $(x * h_1) * h_2 = x * (h_1 * h_2)$
# - Distributive: $x * (h_1 + h_2) = x * h_1 + x * h_2$
# - Identity: $x * \delta = x$

# %%
# Worked Example 2: Rectangular pulse through RC lowpass filter
# Input: x(t) = u(t) - u(t - T) (pulse of width T)
# Impulse response: h(t) = (1/RC)e^(-t/RC) u(t)

# Parameters
T = 1.0  # Pulse width (seconds)
RC = 0.5  # Time constant (seconds)
t = np.linspace(-0.5, 3, 1000)

# Input pulse
x = np.where((t >= 0) & (t < T), 1, 0)

# Impulse response
h = np.where(t >= 0, (1/RC) * np.exp(-t/RC), 0)

# Convolution using numpy
dt = t[1] - t[0]
y_conv = np.convolve(x, h) * dt  # mode='full' (default)
t_conv = np.arange(len(y_conv)) * dt + 2 * t[0]  # correct output time axis

# Theoretical output (derived)
y_theory = np.zeros_like(t)
for i, t_val in enumerate(t):
    if 0 < t_val < T:
        y_theory[i] = 1 - np.exp(-t_val/RC)
    elif t_val >= T:
        y_theory[i] = (np.exp((T-t_val)/RC) - np.exp(-t_val/RC))

# Plot
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 10))

# Input signal
ax1.plot(t, x, 'b-', linewidth=2.5, label='Input: $x(t) = u(t) - u(t-T)$')
ax1.set_ylabel('Amplitude')
ax1.set_title('Input Signal: Rectangular Pulse')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_xlim(-0.5, 3)

# Impulse response
ax2.plot(t, h, 'g-', linewidth=2.5, label='$h(t) = \\frac{1}{RC}e^{-t/RC}u(t)$')
ax2.set_ylabel('Amplitude')
ax2.set_title(f'System Impulse Response (RC = {RC} s)')
ax2.legend()
ax2.grid(True, alpha=0.3)
ax2.set_xlim(-0.5, 3)

# Output (convolution)
ax3.plot(t_conv, y_conv, 'r-', linewidth=2.5, label='Output: $y(t) = x(t) * h(t)$')
ax3.plot(t, y_theory, 'k--', linewidth=1.5, alpha=0.7, label='Theoretical')
ax3.set_xlabel('Time (s)')
ax3.set_ylabel('Amplitude')
ax3.set_title('Output Signal (Convolution Result)')
ax3.legend()
ax3.grid(True, alpha=0.3)
ax3.set_xlim(-0.5, 3)

plt.tight_layout()
plt.show()

print("Key Observation: Convolution causes pulse spreading")
print(f"  - Rise time: ~{3*RC:.2f} s (3×RC)")
print(f"  - This is a preview of Intersymbol Interference (ISI) in digital communications")
# Out:
# Key Observation: Convolution causes pulse spreading
#   - Rise time: ~1.50 s (3×RC)
#   - This is a preview of Intersymbol Interference (ISI) in digital communications

# %% [markdown]
# ## 3. Energy and Power Signals
#
# ### Energy Signals
# A signal with finite energy:
# $$E = \int_{-\infty}^{\infty} |x(t)|^2 dt < \infty$$
#
# **Examples:**
# - Rectangular pulse: $E = A^2T$ (where $A$ = amplitude, $T$ = duration)
# - Exponential decay: $e^{-at}u(t)$ has $E = 1/(2a)$
#
# ### Power Signals
# Average power over infinite time:
# $$P = \lim_{T\to\infty} \frac{1}{T} \int_{-T/2}^{T/2} |x(t)|^2 dt$$
#
# **Examples:**
# - Sinusoid: $A \cos(2\pi ft)$ has $P = A^2/2$
# - DC signal: $P = A^2$
#
# **Key distinction:** A signal cannot have both finite energy AND finite non-zero power.
# - Energy signals: Transient, finite duration (e.g., pulses in digital comm)
# - Power signals: Continuous, often periodic (e.g., carriers, noise)
#
# ### Period of Composite Signals
#
# When adding sinusoids at different frequencies, the **fundamental period** of the composite signal is the **least common multiple (LCM)** of the individual periods:
# - $x_1(t)$ has period $T_1 = 1/f_1$
# - $x_2(t)$ has period $T_2 = 1/f_2$
# - $x(t) = x_1(t) + x_2(t)$ has period $T = \text{LCM}(T_1, T_2)$
#
# For example, if $f_1 = 60$ Hz and $f_2 = 120$ Hz, then $T_1 = 1/60$ s and $T_2 = 1/120$ s, so $T = 1/60$ s (since the 120 Hz component completes exactly 2 cycles per period of the 60 Hz component).

# %%
# Worked Example 3: Calculate energy and power for rectangular pulse
A = 2.0  # Amplitude (volts)
T = 1.0  # Duration (seconds)

# Energy calculation
E = A**2 * T

# Power calculation (limit as observation time → ∞)
# For finite duration pulse, average power → 0

print("Worked Example 3: Rectangular Pulse Energy/Power")
print("="*60)
print(f"Signal: x(t) = {A} V for 0 ≤ t < {T} s, zero elsewhere")
print(f"\nEnergy: E = A²T = {A}² × {T} = {E:.2f} J (Joules)")
print(f"\nAverage Power: P = lim(T'→∞) E/T' = {E}/∞ = 0 W")
print(f"\nConclusion: This is an ENERGY signal (finite energy, zero average power)")

# Example: Sinusoid
print("\n" + "="*60)
print("Example: Sinusoid x(t) = A cos(2πft)")
A_sin = 1.0
P_sin = A_sin**2 / 2
print(f"\nAmplitude: A = {A_sin} V")
print(f"Average Power: P = A²/2 = {P_sin:.2f} W")
print(f"Energy: E = ∫|x(t)|² dt = ∞ (infinite)")
print(f"\nConclusion: This is a POWER signal (finite power, infinite energy)")
# Out:
# Worked Example 3: Rectangular Pulse Energy/Power
# ============================================================
# Signal: x(t) = 2.0 V for 0 ≤ t < 1.0 s, zero elsewhere
#
# Energy: E = A²T = 2.0² × 1.0 = 4.00 J (Joules)
#
# Average Power: P = lim(T'→∞) E/T' = 4.0/∞ = 0 W
#
# Conclusion: This is an ENERGY signal (finite energy, zero average power)
#
# ============================================================
# Example: Sinusoid x(t) = A cos(2πft)
#
# Amplitude: A = 1.0 V
# Average Power: P = A²/2 = 0.50 W
# Energy: E = ∫|x(t)|² dt = ∞ (infinite)
#
# Conclusion: This is a POWER signal (finite power, infinite energy)

# %%
# Visualize energy vs. power signals
t = np.linspace(-2, 8, 1000)

# Energy signal: Exponential decay
a = 1.0
x_energy = np.exp(-a*t) * np.heaviside(t, 1)

# Power signal: Sinusoid
f = 1.0
x_power = np.cos(2*np.pi*f*t)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Energy signal
ax1.plot(t, x_energy, 'b-', linewidth=2.5)
ax1.fill_between(t, 0, x_energy**2, alpha=0.3, label='$|x(t)|^2$ (energy density)')
ax1.set_ylabel('Amplitude')
ax1.set_title('Energy Signal: $x(t) = e^{-t}u(t)$ (finite energy, zero average power)')
ax1.legend()
ax1.grid(True, alpha=0.3)
ax1.set_xlim(-2, 8)

# Power signal
ax2.plot(t, x_power, 'r-', linewidth=2.5)
ax2.axhline(y=np.sqrt(0.5), color='g', linestyle='--', linewidth=2, label='$\\sqrt{P}$ (RMS value)')
ax2.axhline(y=-np.sqrt(0.5), color='g', linestyle='--', linewidth=2)
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Amplitude')
ax2.set_title('Power Signal: $x(t) = \cos(2\pi ft)$ (finite power, infinite energy)')
ax2.legend(loc='upper right')
ax2.grid(True, alpha=0.3)
ax2.set_xlim(-2, 8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Phasor Representation (Review from Lesson 1)
#
# A general sinusoid:
# $$x(t) = A \cos(2\pi ft + \phi)$$
#
# Can be represented using complex exponentials:
# $$x(t) = \text{Re}\{A e^{j\phi} e^{j2\pi ft}\} = \text{Re}\{\tilde{X} e^{j2\pi ft}\}$$
#
# where $\tilde{X} = A e^{j\phi}$ is the **phasor** (time-independent complex number).
#
# **Adding sinusoids at the same frequency:**
# $$x_1(t) + x_2(t) = \text{Re}\{(\tilde{X}_1 + \tilde{X}_2) e^{j\omega t}\}$$
#
# Simply add phasors, then convert back to time domain!

# %%
# Worked Example 4: Add cos(ωt) + cos(ωt + 90°)
A1 = 1
phi1 = 0
A2 = 1
phi2 = np.pi/2  # 90 degrees

# Phasor addition
phasor1 = A1 * np.exp(1j * phi1)
phasor2 = A2 * np.exp(1j * phi2)
phasor_sum = phasor1 + phasor2

A_result = abs(phasor_sum)
phi_result = np.angle(phasor_sum)

print("Worked Example 4: Phasor Addition")
print("="*60)
print(f"Phasor 1: {A1}∠{np.degrees(phi1):.0f}° = {phasor1}")
print(f"Phasor 2: {A2}∠{np.degrees(phi2):.0f}° = {phasor2}")
print(f"\nSum: {A_result:.4f}∠{np.degrees(phi_result):.1f}° = {phasor_sum}")
print(f"\nResult: {A_result:.4f} cos(ωt + {np.degrees(phi_result):.1f}°)")

# Verify in time domain
t = np.linspace(0, 2, 1000)
omega = 2 * np.pi * 1  # 1 Hz
x1 = A1 * np.cos(omega*t + phi1)
x2 = A2 * np.cos(omega*t + phi2)
x_sum = A_result * np.cos(omega*t + phi_result)
x_sum_direct = x1 + x2

plt.figure(figsize=(12, 6))
plt.plot(t, x1, 'b-', linewidth=2, alpha=0.6, label='$x_1(t) = \cos(\omega t)$')
plt.plot(t, x2, 'g-', linewidth=2, alpha=0.6, label='$x_2(t) = \cos(\omega t + 90°)$')
plt.plot(t, x_sum, 'r-', linewidth=3, label=f'$x(t) = {A_result:.2f}\cos(\omega t + {np.degrees(phi_result):.0f}°)$')
plt.plot(t, x_sum_direct, 'k--', linewidth=1.5, alpha=0.5, label='Direct sum (verification)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Phasor Addition: cos(ωt) + cos(ωt + 90°)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\nVerification: Phasor method matches direct addition ✓")
# Out:
# Worked Example 4: Phasor Addition
# ============================================================
# Phasor 1: 1∠0° = (1+0j)
# Phasor 2: 1∠90° = (6.123233995736766e-17+1j)
#
# Sum: 1.4142∠45.0° = (1+1j)
#
# Result: 1.4142 cos(ωt + 45.0°)
# Verification: Phasor method matches direct addition ✓

# %% [markdown]
# ## 5. Analytic Signals and Hilbert Transform
#
# **Motivation:** Real-valued signals have symmetric spectra (positive and negative frequencies). Negative frequencies are redundant!
#
# **Analytic signal:** Complex signal with only positive frequencies.
#
# For real signal $x(t)$:
# $$x_+(t) = x(t) + j\hat{x}(t)$$
#
# where $\hat{x}(t)$ is the **Hilbert transform** of $x(t)$.
#
# **Spectrum:** $X_+(f) = 2X(f)$ for $f > 0$, and $0$ for $f < 0$
#
# **Example:** Analytic signal of cosine
# - $x(t) = \cos(\omega t)$
# - $\hat{x}(t) = \sin(\omega t)$ (Hilbert transform)
# - $x_+(t) = \cos(\omega t) + j \sin(\omega t) = e^{j\omega t}$
#
# **Why it matters:**
# - Elegant representation of bandpass signals
# - Foundation for complex baseband representation (used in SDR)
# - Critical for Single Sideband (SSB) modulation

# %%
# Demonstrate analytic signal for cosine
t = np.linspace(0, 2, 1000)
f = 2  # Hz
omega = 2 * np.pi * f

# Real signal
x = np.cos(omega * t)

# Hilbert transform (for cosine, it's sine)
x_hat = np.sin(omega * t)

# Analytic signal
x_analytic = x + 1j * x_hat

# Using scipy's Hilbert transform
from scipy.signal import hilbert
x_analytic_scipy = hilbert(x)

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 10))

# Real signal
ax1.plot(t, x, 'b-', linewidth=2.5)
ax1.set_ylabel('Amplitude')
ax1.set_title('Real Signal: $x(t) = \cos(\omega t)$')
ax1.grid(True, alpha=0.3)

# Hilbert transform
ax2.plot(t, x_hat, 'p-', linewidth=2.5, label='Theoretical: $\sin(\omega t)$')
ax2.plot(t, x_analytic_scipy.imag, 'r--', linewidth=2, label='SciPy Hilbert')
ax2.set_ylabel('Amplitude')
ax2.set_title('Hilbert Transform: $\hat{x}(t)$ (90° phase shift)')
ax2.legend(loc='upper right')
ax2.grid(True, alpha=0.3)

# Analytic signal magnitude and phase
ax3_twin = ax3.twinx()
ax3.plot(t, np.abs(x_analytic), 'r-', linewidth=2.5, label='Magnitude')
ax3_twin.plot(t, np.angle(x_analytic), 'b-', linewidth=2.5, alpha=0.7, label='Phase (rad)')
ax3.set_xlabel('Time (s)')
ax3.set_ylabel('Magnitude', color='r')
ax3_twin.set_ylabel('Phase (radians)', color='b')
ax3.set_title('Analytic Signal: $x_+(t) = e^{j\omega t}$')
ax3.legend(loc='upper left')
ax3_twin.legend(loc='upper right')
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("Key Observations:")
print("  - Hilbert transform shifts phase by -90° (cosine → sine)")
print("  - Analytic signal has constant magnitude (= 1 for unit cosine)")
print("  - Phase increases linearly (rotating phasor)")
print("  - Contains only positive frequency component")
# Out:
# Key Observations:
#   - Hilbert transform shifts phase by -90° (cosine → sine)
#   - Analytic signal has constant magnitude (= 1 for unit cosine)
#   - Phase increases linearly (rotating phasor)
#   - Contains only positive frequency component

# %% [markdown]
# ## 6. I/Q Representation
#
# In Section 4, we saw that a sinusoid $A\cos(2\pi f_c t + \phi)$ can be written using a phasor $\tilde{X} = Ae^{j\phi}$.
# In Section 5, we met the analytic signal and complex baseband.
# Now we introduce the **I/Q representation** — the standard way modern radios (including the RTL-SDR we will use in lab) describe signals.
#
# ### In-Phase and Quadrature Components
#
# Any bandpass signal at carrier frequency $f_c$ can be written as:
#
# $$s(t) = I(t)\cos(2\pi f_c t) - Q(t)\sin(2\pi f_c t)$$
#
# where:
# - $I(t)$ is the **in-phase** component (aligned with the cosine carrier)
# - $Q(t)$ is the **quadrature** component (aligned with the sine carrier, 90° "in quadrature")
#
# The cosine and sine carriers are **orthogonal** — they are 90° apart, which is why sine is called the "quadrature" component. This orthogonality means I and Q carry independent information on the same carrier frequency.
#
# ### Connection to Phasors
#
# Recall from Section 4 that a phasor $\tilde{X} = Ae^{j\phi} = A\cos\phi + jA\sin\phi$ has a real part and an imaginary part. The I/Q components are exactly these:
#
# $$I = A\cos\phi, \quad Q = A\sin\phi$$
#
# ### Rectangular ↔ Polar Conversion
#
# Given I and Q, we can find the amplitude and phase:
#
# $$A = \sqrt{I^2 + Q^2}, \quad \phi = \arctan\!\left(\frac{Q}{I}\right)$$
#
# We can verify this by expanding $A\cos(2\pi f_c t + \phi)$ using the cosine addition formula:
#
# $$A\cos(2\pi f_c t + \phi) = \underbrace{A\cos\phi}_{I}\cos(2\pi f_c t) - \underbrace{A\sin\phi}_{Q}\sin(2\pi f_c t)$$
#
# which matches our I/Q form exactly.
#
# ### Complex Envelope
#
# The **complex envelope** (also called the **complex baseband signal**) packages I and Q into a single complex number:
#
# $$\tilde{s}(t) = I(t) + jQ(t)$$
#
# This is the signal that software-defined radios (SDRs) actually output — a stream of complex I/Q samples. The RF signal is reconstructed by:
#
# $$s(t) = \text{Re}\{\tilde{s}(t)\, e^{j2\pi f_c t}\}$$
#
# ### Why I/Q Matters
#
# | Application | How I/Q is Used |
# |-------------|----------------|
# | SDR (RTL-SDR, HackRF) | Hardware outputs I/Q sample pairs |
# | WiFi (802.11) | QAM modulation encodes bits into I/Q symbols |
# | Digital modulation (BPSK, QPSK, QAM) | Each constellation point is an (I, Q) pair |
# | Cell phones (LTE, 5G) | All modulation uses I/Q processing |
#
# **Why do SDRs use I/Q instead of sampling the RF signal directly?** Consider a WiFi signal at $f_c = 2.4$ GHz. To digitize that RF carrier directly, an analog-to-digital converter (ADC) would need to sample at more than $2 \times 2.4 = 4.8$ billion samples per second (by Nyquist's theorem). That's impractical. Instead, the SDR hardware mixes the signal down to baseband, producing $I(t)$ and $Q(t)$, which only vary at the rate of the modulation bandwidth (e.g., 20 MHz for WiFi). The ADC only needs to sample at ~40 MHz — over 100× slower. No information is lost because the complex envelope $\tilde{s}(t) = I + jQ$ fully captures the signal's amplitude and phase.
#
# We will use I/Q extensively starting in Lesson 13 (BPSK), Lesson 20 (QPSK/QAM), and in the GNU Radio labs.

# %%
# Worked Example 5: I/Q Representation
# A communication signal with I = 5 V, Q = 12 V at fc = 900 MHz

# --- Define I/Q values ---
I_val = 5   # In-phase component (V)
Q_val = 12  # Quadrature component (V)
fc = 900e6  # Carrier frequency (Hz)

# --- Rectangular to polar conversion ---
A = np.sqrt(I_val**2 + Q_val**2)
phi = np.arctan2(Q_val, I_val)  # Phase angle (radians)

print("Worked Example 5: I/Q Representation")
print("=" * 60)
print(f"I = {I_val} V,  Q = {Q_val} V,  fc = {fc/1e6:.0f} MHz")
print(f"\nAmplitude:  A = sqrt({I_val}² + {Q_val}²) = sqrt({I_val**2} + {Q_val**2}) = {A:.2f} V")
print(f"Phase:      φ = arctan2(Q/I) = arctan2({Q_val}/{I_val}) = {np.degrees(phi):.2f}°")
print(f"\nSingle sinusoid form:")
print(f"  s(t) = {A:.2f} cos(2π·{fc/1e6:.0f} MHz·t + {np.degrees(phi):.2f}°)")
print(f"\nComplex envelope:")
print(f"  s̃(t) = {I_val} + j{Q_val} = {A:.2f}∠{np.degrees(phi):.2f}°")

# --- Visualization ---
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Panel 1: I/Q Plane (constellation diagram)
ax1 = axes[0]
# Draw I and Q components as dashed projections
ax1.plot([I_val, I_val], [0, Q_val], 'g--', linewidth=1.5, alpha=0.7)
ax1.plot([0, I_val], [Q_val, Q_val], 'purple', linestyle='--', linewidth=1.5, alpha=0.7)
# Draw the signal vector
ax1.quiver(0, 0, I_val, Q_val, angles='xy', scale_units='xy', scale=1,
           color='darkblue', width=0.015, zorder=3)
ax1.scatter(I_val, Q_val, s=200, c='red', marker='o', edgecolors='black',
            linewidths=2, zorder=4)
# Annotate
ax1.annotate(f'({I_val}, {Q_val})', xy=(I_val, Q_val), xytext=(I_val+0.8, Q_val+0.8),
             fontsize=11, bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.7))
ax1.text(I_val/2 - 1.5, Q_val/2 + 1, f'A = {A:.1f} V\nφ = {np.degrees(phi):.1f}°',
         fontsize=10, bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.7))
# Draw arc for angle
theta_arc = np.linspace(0, phi, 50)
r_arc = 3
ax1.plot(r_arc*np.cos(theta_arc), r_arc*np.sin(theta_arc), 'k-', linewidth=1.5)
# Labels
ax1.set_xlabel('I (In-phase) [V]')
ax1.set_ylabel('Q (Quadrature) [V]')
ax1.set_title('I/Q Plane')
ax1.grid(True, alpha=0.3)
ax1.axhline(y=0, color='k', linewidth=1)
ax1.axvline(x=0, color='k', linewidth=1)
ax1.set_xlim(-2, 15)
ax1.set_ylim(-2, 15)
ax1.set_aspect('equal')

# Panel 2: Time-domain decomposition (use low fc for visibility)
ax2 = axes[1]
fc_display = 5  # Use 5 Hz so waveforms are visible
t = np.linspace(0, 1, 1000)
i_component = I_val * np.cos(2*np.pi*fc_display*t)
q_component = -Q_val * np.sin(2*np.pi*fc_display*t)
s_t = i_component + q_component
ax2.plot(t, i_component, 'b-', linewidth=1.5, alpha=0.6, label=f'I·cos = {I_val}·cos(2πf_c t)')
ax2.plot(t, q_component, 'g-', linewidth=1.5, alpha=0.6, label=f'−Q·sin = −{Q_val}·sin(2πf_c t)')
ax2.plot(t, s_t, 'r-', linewidth=2.5, label=f's(t) = {A:.1f}·cos(2πf_c t + {np.degrees(phi):.1f}°)')
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Amplitude (V)')
ax2.set_title(f'Time-Domain Components (fc = {fc_display} Hz for visibility)')
ax2.legend(fontsize=9, loc='upper right')
ax2.grid(True, alpha=0.3)

# Panel 3: Effect of changing I and Q
ax3 = axes[2]
iq_examples = [(5, 0, 'b', 'I=5, Q=0 (pure cosine)'),
               (0, 5, 'g', 'I=0, Q=5 (pure −sine)'),
               (5, 5, 'purple', 'I=5, Q=5 (45°)'),
               (5, 12, 'r', 'I=5, Q=12 (our example)')]
for I_ex, Q_ex, color, label in iq_examples:
    ax3.scatter(I_ex, Q_ex, s=150, c=color, edgecolors='black', linewidths=1.5, zorder=3)
    ax3.quiver(0, 0, I_ex, Q_ex, angles='xy', scale_units='xy', scale=1,
               color=color, width=0.008, alpha=0.8, zorder=2)
    ax3.annotate(label, xy=(I_ex, Q_ex), xytext=(I_ex+0.5, Q_ex+0.5),
                 fontsize=8, color=color)
ax3.set_xlabel('I (In-phase) [V]')
ax3.set_ylabel('Q (Quadrature) [V]')
ax3.set_title('Effect of Changing I and Q')
ax3.grid(True, alpha=0.3)
ax3.axhline(y=0, color='k', linewidth=1)
ax3.axvline(x=0, color='k', linewidth=1)
ax3.set_xlim(-2, 15)
ax3.set_ylim(-2, 15)
ax3.set_aspect('equal')

plt.tight_layout()
plt.show()

print("\nKey Observations:")
print("  - I = 5, Q = 0: Signal is a pure cosine (in-phase only)")
print("  - I = 0, Q = 5: Signal is a pure negative sine (quadrature only)")
print("  - I = 5, Q = 5: Equal I and Q → 45° phase shift, amplitude = 5√2 ≈ 7.07")
print(f"  - I = 5, Q = 12: Our example → {np.degrees(phi):.1f}° phase, amplitude = {A:.0f} V")
print("  - The I/Q plane IS the complex plane for the envelope")
# Out:
# Worked Example 5: I/Q Representation
# ============================================================
# I = 5 V,  Q = 12 V,  fc = 900 MHz
#
# Amplitude:  A = sqrt(5² + 12²) = sqrt(25 + 144) = 13.00 V
# Phase:      φ = arctan2(Q/I) = arctan2(12/5) = 67.38°
#
# Single sinusoid form:
#   s(t) = 13.00 cos(2π·900 MHz·t + 67.38°)
#
# Complex envelope:
#   s̃(t) = 5 + j12 = 13.00∠67.38°
# Key Observations:
#   - I = 5, Q = 0: Signal is a pure cosine (in-phase only)
#   - I = 0, Q = 5: Signal is a pure negative sine (quadrature only)
#   - I = 5, Q = 5: Equal I and Q → 45° phase shift, amplitude = 5√2 ≈ 7.07
#   - I = 5, Q = 12: Our example → 67.4° phase, amplitude = 13 V
#   - The I/Q plane IS the complex plane for the envelope

# %% [markdown]
# ### I/Q Representation: Key Formulas
#
# | Quantity | Formula |
# |----------|---------|
# | Bandpass signal | $s(t) = I(t)\cos(2\pi f_c t) - Q(t)\sin(2\pi f_c t)$ |
# | Complex envelope | $\tilde{s}(t) = I(t) + jQ(t)$ |
# | Amplitude | $A = \sqrt{I^2 + Q^2}$ |
# | Phase | $\phi = \arctan(Q/I)$ |
# | Reconstruction | $s(t) = \text{Re}\{\tilde{s}(t)\, e^{j2\pi f_c t}\}$ |
#
# **Connection to Homework 1:** Problem 5 asks you to apply these formulas to a 900 MHz signal. Problems 9 and 10 extend I/Q to a WiFi signal and conceptual understanding of complex envelopes.

# %% [markdown]
# ## 7. Practice Problems
#
# Try these exercises to reinforce your understanding:
#
# 1. **Convolution:** What is $\delta(t-2) * u(t)$?
# 2. **Energy:** Calculate energy of $x(t) = 3 \cdot \text{rect}(t/4)$ (rectangular pulse, amplitude 3, width 4)
# 3. **Power:** What is average power of $x(t) = 2\cos(2\pi \cdot 50t) + \sin(2\pi \cdot 100t)$?
# 4. **Phasor:** Add $3\angle 30° + 4\angle 120°$
# 5. **I/Q to Polar:** A signal has $I = 3$ V and $Q = 4$ V at carrier frequency 1 GHz. Find the amplitude $A$, the phase $\phi$, and the complex envelope.
# 6. **Polar to I/Q:** Express $s(t) = 10\cos(2\pi f_c t + 30°)$ in I/Q form. Find $I$ and $Q$.

# %%
# Solution space for practice problems
# Try solving on your own first!

print("Practice Problem Solutions")
print("="*60)

# Problem 1: δ(t-2) * u(t)
print("\n1. Convolution: δ(t-2) * u(t)")
print("   Using shift property: δ(t-2) * u(t) = u(t-2)")
print("   Result: Step function shifted right by 2 seconds")

# Problem 2: Energy of rectangular pulse
A = 3
T = 4
E = A**2 * T
print(f"\n2. Energy: x(t) = 3·rect(t/4)")
print(f"   E = A²T = {A}² × {T} = {E} J")

# Problem 3: Power of sum of sinusoids
A1 = 2
A2 = 1
P1 = A1**2 / 2
P2 = A2**2 / 2
P_total = P1 + P2  # Independent frequencies, powers add
print(f"\n3. Power: x(t) = 2cos(2π·50t) + sin(2π·100t)")
print(f"   P₁ = (2)²/2 = {P1} W")
print(f"   P₂ = (1)²/2 = {P2} W")
print(f"   P_total = {P1} + {P2} = {P_total} W")

# Problem 4: Phasor addition
p1 = 3 * np.exp(1j * np.radians(30))
p2 = 4 * np.exp(1j * np.radians(120))
p_sum = p1 + p2
print(f"\n4. Phasor: 3∠30° + 4∠120°")
print(f"   3∠30° = {p1:.4f}")
print(f"   4∠120° = {p2:.4f}")
print(f"   Sum = {abs(p_sum):.4f}∠{np.angle(p_sum, deg=True):.2f}°")

# Problem 5: I/Q to Polar
I5, Q5 = 3, 4
A5 = np.sqrt(I5**2 + Q5**2)
phi5 = np.arctan2(Q5, I5)
print(f"\n5. I/Q to Polar: I = {I5} V, Q = {Q5} V")
print(f"   A = sqrt({I5}² + {Q5}²) = {A5:.2f} V")
print(f"   φ = arctan2({Q5}, {I5}) = {np.degrees(phi5):.2f}°")
print(f"   Complex envelope: {I5} + j{Q5} = {A5:.2f}∠{np.degrees(phi5):.2f}°")
print(f"   s(t) = {A5:.2f}cos(2π·1 GHz·t + {np.degrees(phi5):.2f}°)")

# Problem 6: Polar to I/Q
A6 = 10
phi6_deg = 30
phi6 = np.radians(phi6_deg)
I6 = A6 * np.cos(phi6)
Q6 = A6 * np.sin(phi6)
print(f"\n6. Polar to I/Q: s(t) = {A6}cos(2πf_c t + {phi6_deg}°)")
print(f"   Expand: A cos(2πf_c t + φ) = A cos(φ) cos(2πf_c t) - A sin(φ) sin(2πf_c t)")
print(f"   I = A·cos(φ) = {A6}·cos({phi6_deg}°) = {I6:.2f} V")
print(f"   Q = A·sin(φ) = {A6}·sin({phi6_deg}°) = {Q6:.2f} V")
print(f"   Complex envelope: {I6:.2f} + j{Q6:.2f}")
# Out:
# Practice Problem Solutions
# ============================================================
#
# 1. Convolution: δ(t-2) * u(t)
#    Using shift property: δ(t-2) * u(t) = u(t-2)
#    Result: Step function shifted right by 2 seconds
#
# 2. Energy: x(t) = 3·rect(t/4)
#    E = A²T = 3² × 4 = 36 J
#
# 3. Power: x(t) = 2cos(2π·50t) + sin(2π·100t)
#    P₁ = (2)²/2 = 2.0 W
#    P₂ = (1)²/2 = 0.5 W
#    P_total = 2.0 + 0.5 = 2.5 W
#
# 4. Phasor: 3∠30° + 4∠120°
#    3∠30° = 2.5981+1.5000j
#    4∠120° = -2.0000+3.4641j
#    Sum = 5.0000∠83.13°
#
# 5. I/Q to Polar: I = 3 V, Q = 4 V
#    A = sqrt(3² + 4²) = 5.00 V
#    φ = arctan2(4, 3) = 53.13°
#    Complex envelope: 3 + j4 = 5.00∠53.13°
#    s(t) = 5.00cos(2π·1 GHz·t + 53.13°)
#
# 6. Polar to I/Q: s(t) = 10cos(2πf_c t + 30°)
#    Expand: A cos(2πf_c t + φ) = A cos(φ) cos(2πf_c t) - A sin(φ) sin(2πf_c t)
#    I = A·cos(φ) = 10·cos(30°) = 8.66 V
#    Q = A·sin(φ) = 10·sin(30°) = 5.00 V
#    Complex envelope: 8.66 + j5.00

# %% [markdown]
# ## Key Concepts Summary
#
# 1. **Impulse δ(t) and step u(t)** are fundamental building blocks for signal analysis
# 2. **Convolution** describes system response: $y = x * h$
#    - Causes pulse spreading (preview of ISI)
# 3. **Energy signals** (finite E) vs. **power signals** (finite P)
#    - Energy: Transient pulses (digital comm)
#    - Power: Continuous signals (carriers, noise)
# 4. **Phasors** simplify sinusoid arithmetic at same frequency
# 5. **Analytic signals** eliminate negative frequency redundancy
#    - Foundation for complex baseband representation
#    - Critical for SSB modulation
# 6. **I/Q representation** separates signals into in-phase and quadrature components
#    - Complex envelope: $\tilde{s}(t) = I(t) + jQ(t)$
#    - Foundation for all digital modulation (BPSK, QPSK, QAM)
#    - SDRs output I/Q samples directly
#
# ## Next Lesson Preview
# Lesson 3: Fourier Analysis Essentials
# - Fourier series for periodic signals
# - Fourier transforms for aperiodic signals
# - Spectral visualization
# - Python Lab: Hands-on Fourier analysis
